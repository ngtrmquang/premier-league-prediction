# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
datasets = [
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-2526.csv", "season": "25/26"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-2425.csv", "season": "24/25"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-2324.csv", "season": "23/24"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-2223.csv", "season": "22/23"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-2122.csv", "season": "21/22"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-2021.csv", "season": "20/21"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-1920.csv", "season": "19/20"}, 
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-1819.csv", "season": "18/19"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-1718.csv", "season": "17/18"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-1617.csv", "season": "16/17"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-1516.csv", "season": "15/16"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-1415.csv", "season": "14/15"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-1314.csv", "season": "13/14"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-1213.csv", "season": "12/13"},
    {"file": r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-1112.csv", "season": "11/12"},
]

df_list = []
for i in datasets:
    df_prem = pd.read_csv(i["file"])
    df_prem['season'] = i['season']
    df_list.append(df_prem)

df = pd.concat(df_list, ignore_index=True)

# %%
df_merge = df.copy()

col_int = df_merge.select_dtypes(include=['int64']).columns
df_merge[col_int] = df_merge[col_int].astype('int8')

df_merge['Date'] = pd.to_datetime(df_merge['Date']).dt.date
df_merge = df_merge.sort_values('Date', ascending=False)

# %%
df_merge.sample(20)
# Out:
#             Date     HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 2996  2019-04-20  Bournemouth         Fulham     0     1   A     0     0   D
# 96    2025-11-01    Liverpool    Aston Villa     2     0   H     1     0   H
# 416   2024-09-14  Aston Villa        Everton     3     2   H     1     2   A
# 2255  2021-05-15     Brighton       West Ham     1     1   D     0     0   D
# 1567  2021-09-19     Brighton      Leicester     2     1   H     1     0   H
# 5329  2011-08-20      Arsenal      Liverpool     0     2   A     0     0   D
# 860   2023-11-04       Fulham     Man United     0     1   A     0     0   D
# 2980  2019-04-06  Bournemouth        Burnley     1     3   A     1     2   A
# 1977  2020-11-08      Arsenal    Aston Villa     0     3   A     0     1   A
# 3046  2017-08-12      Watford      Liverpool     3     3   D     2     1   H
# 5090  2012-12-08  Aston Villa          Stoke     0     0   D     0     0   D
# ...

# %%
df_test = pd.read_csv(r'C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-2627.csv')

df_test['Matchday'] = df_test['Matchday'].astype('int8')
df_test['Date'] = pd.to_datetime(df_test['Date']).dt.date
df_test = df_test.sort_values('Date', ascending=False)

# %%
df_merge.to_parquet(
    r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\pl_combined.parquet",
    engine="pyarrow",
    compression="snappy",
    index=False,
)
df_test.to_parquet(
    r"C:\Users\Quang\Documents\Code\Self Project\PL Prediction\dataset\season-2627.parquet",
    engine="pyarrow",
    compression="snappy",
    index=False,
)
